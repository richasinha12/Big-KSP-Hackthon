# %%
import pandas as pd

# %%
# Load the dataset
data = pd.read_csv('newmodified_dataset.csv')

# %%
data.head()
# Out:
#   District_Name    UnitName     FIR Type      FIR_Stage      Complaint_Mode  \
# 0      Bagalkot  Amengad PS  Non Heinous        Dis/Acq             Written
# 1      Bagalkot  Amengad PS  Non Heinous      Convicted  Sue-moto by Police
# 2      Bagalkot  Amengad PS  Non Heinous      Convicted  Sue-moto by Police
# 3      Bagalkot  Amengad PS  Non Heinous      Convicted             Written
# 4      Bagalkot  Amengad PS      Heinous  Pending Trial             Written
#
#                      CrimeGroup_Name                 CrimeHead_Name  Latitude  \
# 0                              POCSO                         Others       0.0
# 1          KARNATAKA POLICE ACT 1963           Street Gambling (87)       0.0
# 2          KARNATAKA POLICE ACT 1963  Gambling - Matka (78 Class C)       0.0
# 3  MOTOR VEHICLE ACCIDENTS NON-FATAL              National Highways       0.0
# 4      MOTOR VEHICLE ACCIDENTS FATAL                    Other Roads       0.0
#
# ...

# %%
# Group the data by location and sum the accused counts
total_accused_count_by_location = data.groupby('Location')['Accused_Count'].sum()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 28 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   District_Name                1000 non-null   object
#  1   UnitName                     1000 non-null   object
#  2   FIR Type                     1000 non-null   object
#  3   FIR_Stage                    1000 non-null   object
#  4   Complaint_Mode               987 non-null    object
#  5   CrimeGroup_Name              1000 non-null   object
#  6   CrimeHead_Name               1000 non-null   object
#  7   Latitude                     1000 non-null   float64
#  8   Longitude                    1000 non-null   float64
#  9   ActSection                   1000 non-null   object
#  10  Place of Offence             1000 non-null   object
#  11  Distance from PS             1000 non-null   object
#  12  Beat_Name                    1000 non-null   object
# ...

# %%
# Group the data by location and sum the accused counts
total_accused_count_by_location = data.groupby('Village_Area_Name')['Accused Count'].sum()

# %%
total_accused_count_by_location
# Out:
# Village_Area_Name
# AIHOLE           407
# AMBLIKOPPA         5
# AMINAGAD         366
# BASANAL            2
# BASARIKATTI        1
# BENAL              3
# CHIKKAMAGI         2
# DAMMUR           394
# GUDUR            241
# KALLIGUDDA         0
# KAMATAGI         384
# KAMATAGI ONE      33
# KELUR             24
# KYADIGERI          1
# MADAPUR          328
# MURUDI            26
# RAKKASAGI          5
# RAMATHAL          13
# SIDDANAKOLLA      14
# SULEBAVI         292
# SULEBHAVI TWO      4
# UPANAL           252
# Name: Accused Count, dtype: int64
